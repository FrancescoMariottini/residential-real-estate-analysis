# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Set the url we want to import the data from

# %%
url = 'https://raw.githubusercontent.com/FrancescoMariottini/project3/main/inputs/sales_data_final_final.csv'

# %% [markdown]
# ### Step 3. Assign it to a pandas DataFrame

# %%
df = pd.read_csv(url)
df
# Out:
# /home/jo/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (9,11,12,17,18,19) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#        source  hyperlink  locality  postcode  house_is    property_subtype   \
# 0            6    8901695     4180    4180.0       True  MIXED_USE_BUILDING
# 1            6    8747010     8730    8730.0       True               VILLA
# 2            6    8775843     4020    4020.0       True     APARTMENT_BLOCK
# 3            6    8910441     1200    1200.0       True               HOUSE
# 4            6    8758672     1190    1190.0       True  MIXED_USE_BUILDING
# ...        ...        ...      ...       ...        ...                 ...
# 87475        3    8790149      NaN    8400.0      False           Apartment
# 87476        3    8913091      NaN    1800.0      False           Apartment
# 87477        3    8913078      NaN    7500.0      False           Apartment
# 87478        3    8863524      NaN    1150.0      False           Apartment
# 87479        3    8913056      NaN    9230.0      False           Apartment
#
#           price      sale rooms_number  area   ... open_fire  terrace   \
# 0        295000       NaN             3   242  ...      False     True
# 1        675000       NaN             4   349  ...      False    False
# 2        250000       NaN             5   303  ...      False    False
# 3        545000       NaN             4   235  ...      False    False
# 4        500000       NaN             2   220  ...      False    False
# ...         ...       ...           ...   ...  ...        ...      ...
# 87475  €169,000  for sale             2    80  ...          0      NaN
# 87476  €390,000  for sale             4   239  ...          0      NaN
# 87477  €150,000  for sale             2    99  ...          0      NaN
# 87478  €250,000  for sale             1    80  ...          0      NaN
# 87479  €142,000  for sale             1    83  ...          0      NaN
#
#       terrace_area garden  garden_area land_surface land_plot_surface   \
# 0               36    True        1000         1403               1403
# 1                0    True         977         1526               1526
# 2                0   False           0          760                760
# 3                0   False           0           63                 63
# 4                0    True          60          193                193
# ...            ...     ...         ...          ...                ...
# 87475            4     NaN           0          NaN                NaN
# 87476            0     NaN           0          NaN                NaN
# 87477            0     NaN           0          NaN                NaN
# 87478            0     NaN           0          NaN                NaN
# 87479            0     NaN          38          NaN                NaN
#
#       facades_number  swimming_pool_has  building_state
# 0                   0              False            GOOD
# 1                   0              False          AS_NEW
# 2                   0              False     TO_RENOVATE
# 3                   0              False  JUST_RENOVATED
# 4                   0              False          AS_NEW
# ...               ...                ...             ...
# 87475               0                  0               0
# 87476               0                  0               0
# 87477               0                  0            Good
# 87478               0                  0            Good
# 87479               2                  0            Good
#
# [87480 rows x 22 columns]

# %%
df.dtypes
# Out:
# source                  int64
# hyperlink              object
# locality               object
# postcode              float64
# house_is                 bool
# property_subtype       object
# price                  object
# sale                   object
# rooms_number           object
# area                   object
# kitchen_has            object
# furnished              object
# open_fire              object
# terrace                object
# terrace_area           object
# garden                 object
# garden_area            object
# land_surface           object
# land_plot_surface      object
# facades_number         object
# swimming_pool_has      object
# building_state         object
# dtype: object
